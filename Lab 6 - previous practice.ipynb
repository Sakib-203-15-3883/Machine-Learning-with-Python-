# %%
import numpy as np
import pandas as pd
import matplotlib as plot
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
dataset = pd.read_csv("Medical dataset.csv")

# %%
dataset
# Out:
#     Unnamed: 0  RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY  \
# 0            1    2448    1    195.0   39  106.0   70.0         0        0
# 1            2    2448    1    209.0   52  121.0   66.0         0        0
# 2            3    6238    2    250.0   46  121.0   81.0         0        0
# 3            4    6238    2    260.0   52  105.0   69.5         0        0
# 4            5    6238    2    237.0   58  108.0   66.0         0        0
# ..         ...     ...  ...      ...  ...    ...    ...       ...      ...
# 64          65   54224    1    294.0   47  102.0   68.0         1       20
# 65          66   55965    2    260.0   60  110.0   72.5         0        0
# 66          67   55965    2    256.0   66  126.0   82.0         0        0
# 67          68   55965    2    298.0   72  109.0   60.0         0        0
# 68          69   63156    1    225.0   35  132.0   91.0         1       20
#
# ...

# %%
totCholMean = dataset["TOTCHOL"].mean()
totCholMean
# Out:
# 246.41538461538462

# %%
ageMean = dataset["AGE"].mean()
ageMean
# Out:
# 51.57971014492754

# %%
sysbpMean = dataset["SYSBP"].mean()
sysbpMean
# Out:
# 135.80434782608697

# %%
bmiMean = dataset["BMI"].mean()
bmiMean
# Out:
# 26.336323529411768

# %%
totCholMedian = dataset["TOTCHOL"].median()
totCholMedian
# Out:
# 244.0

# %%
ageMedian = dataset["AGE"].median()
ageMedian
# Out:
# 51.0

# %%
sysbpMedian = dataset["SYSBP"].median()
sysbpMedian
# Out:
# 133.0

# %%
bmiMedian = dataset["BMI"]
bmiMedian
# Out:
# 0     26.97
# 1       NaN
# 2     28.73
# 3     29.43
# 4     28.50
#       ...
# 64    24.18
# 65    26.59
# 66    25.43
# 67    26.20
# 68    26.09
# Name: BMI, Length: 69, dtype: float64

# %%
dataset.corr()
# Out:
#             Unnamed: 0    RANDID           SEX   TOTCHOL       AGE     SYSBP  \
# Unnamed: 0    1.000000  0.982953 -7.718170e-03 -0.002286  0.004152 -0.066300
# RANDID        0.982953  1.000000 -5.611637e-03 -0.013541 -0.003537 -0.099407
# SEX          -0.007718 -0.005612  1.000000e+00  0.017389  0.149993 -0.170288
# TOTCHOL      -0.002286 -0.013541  1.738936e-02  1.000000  0.167828 -0.230222
# AGE           0.004152 -0.003537  1.499928e-01  0.167828  1.000000  0.214214
# SYSBP        -0.066300 -0.099407 -1.702879e-01 -0.230222  0.214214  1.000000
# DIABP        -0.107412 -0.119176 -2.984460e-01 -0.244827 -0.127514  0.788014
# CURSMOKE      0.129540  0.150145 -8.199201e-02  0.159184 -0.227569 -0.075900
# CIGPDAY       0.108671  0.124460 -9.168444e-03  0.169659 -0.136267 -0.132128
# BMI          -0.086330 -0.056205  2.038519e-01 -0.118181  0.215510  0.365472
# DIABETES      0.089206  0.079348  1.507557e-01  0.065738  0.196228  0.324574
# ...

# %%
# Label Encoder

# %%
le = LabelEncoder()

# %%
totCholLE = le.fit_transform(dataset["TOTCHOL"])
ageLE = le.fit_transform(dataset["AGE"])
sysbpLE = le.fit_transform(dataset["SYSBP"])
bmiLE = le.fit_transform(dataset["BMI"])

# %%
totCholLE
# Out:
# array([ 4,  8, 26, 30, 22, 24, 36, 15, 19, 37, 48, 49, 17, 18, 12,  7, 12,
#        45, 49, 46, 30, 41, 35, 15, 29,  9, 27, 49, 40, 25, 42, 38, 47, 15,
#         0, 16,  5, 31, 13, 19, 14, 11, 40,  4, 32, 10,  4,  6,  1,  3, 23,
#        16,  2, 33, 49, 20, 34, 36, 11, 28, 21, 33, 44, 39, 42, 30, 28, 43,
#        15], dtype=int64)

# %%
ageLE
# Out:
# array([ 2, 14,  8, 14, 20, 10, 16, 22, 27,  8, 13, 20,  5, 11, 17, 24, 28,
#         7, 13, 19, 14, 20, 25,  5, 11, 17, 12, 18, 23,  5,  8, 14,  3,  9,
#        15,  2,  8, 13,  1, 10, 16, 21,  8,  1,  6, 11,  3,  9, 15,  4, 10,
#        16,  5, 11, 17, 14, 20, 25, 14, 20, 25,  6, 12, 18,  9, 21, 26, 29,
#         0], dtype=int64)

# %%
sysbpLE
# Out:
# array([ 3, 11, 11,  2,  4, 17, 30, 37, 50, 19,  5, 40, 49, 48, 49, 26, 36,
#         0,  6,  7, 31, 21, 46, 43, 34, 47, 22, 17, 10, 20, 32, 45, 14, 10,
#        14,  9, 24, 30, 29, 26, 28, 33,  8, 12, 27, 44, 27, 42, 39,  4, 12,
#        15, 13, 16, 18, 35, 43, 41, 21, 38, 37, 25, 23, 21,  1,  7, 15,  5,
#        21], dtype=int64)

# %%
bmiLE
# Out:
# array([41, 65, 47, 49, 45, 27, 27, 46, 52, 16, 19, 24, 53, 56, 54, 59, 64,
#         4, 10,  9, 35, 28, 30, 20, 42, 48, 14,  0,  8, 43, 34, 37, 55, 44,
#        39, 11,  1, 25,  2, 12,  5, 15, 18, 17, 51, 57, 40, 33, 36,  3,  6,
#         3, 50, 62, 63, 61, 60, 58, 26, 13, 22,  7, 21, 13, 23, 38, 29, 32,
#        31], dtype=int64)
