# %%
import numpy as np
import pandas as pd
import matplotlib as plot
import seaborn as sns

# %%
dataset = pd.read_csv("Medical dataset.csv")

# %%
dataset
# Out:
#     Unnamed: 0  RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY  \
# 0            1    2448    1    195.0   39  106.0   70.0         0        0
# 1            2    2448    1    209.0   52  121.0   66.0         0        0
# 2            3    6238    2    250.0   46  121.0   81.0         0        0
# 3            4    6238    2    260.0   52  105.0   69.5         0        0
# 4            5    6238    2    237.0   58  108.0   66.0         0        0
# ..         ...     ...  ...      ...  ...    ...    ...       ...      ...
# 64          65   54224    1    294.0   47  102.0   68.0         1       20
# 65          66   55965    2    260.0   60  110.0   72.5         0        0
# 66          67   55965    2    256.0   66  126.0   82.0         0        0
# 67          68   55965    2    298.0   72  109.0   60.0         0        0
# 68          69   63156    1    225.0   35  132.0   91.0         1       20
#
# ...

# %%
dataset.head()
# Out:
#    Unnamed: 0  RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY  \
# 0           1    2448    1    195.0   39  106.0   70.0         0        0
# 1           2    2448    1    209.0   52  121.0   66.0         0        0
# 2           3    6238    2    250.0   46  121.0   81.0         0        0
# 3           4    6238    2    260.0   52  105.0   69.5         0        0
# 4           5    6238    2    237.0   58  108.0   66.0         0        0
#
#      BMI  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0  26.97  ...    1         0    8766    6438      6438     6438      8766
# 1    NaN  ...    1         0    8766    6438      6438     6438      8766
# 2  28.73  ...    0         0    8766    8766      8766     8766      8766
# 3  29.43  ...    0         0    8766    8766      8766     8766      8766
# 4  28.50  ...    0         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP
# 0     6438     8766     8766
# ...

# %%
dataset["SEX"].value_counts()
# Out:
# 2    46
# 1    23
# Name: SEX, dtype: int64

# %%
dataset["TOTCHOL"].value_counts()
# Out:
# 225.0    4
# 260.0    3
# 195.0    3
# 270.0    2
# 232.0    2
# 283.0    2
# 291.0    2
# 256.0    2
# 294.0    2
# 226.0    2
# 220.0    2
# 215.0    2
# 320.0    1
# 212.0    1
# 190.0    1
# 209.0    1
# 272.0    1
# 185.0    1
# 245.0    1
# 292.0    1
# 288.0    1
# 201.0    1
# 265.0    1
# 313.0    1
# 211.0    1
# 285.0    1
# 230.0    1
# 264.0    1
# 258.0    1
# 343.0    1
# 254.0    1
# 247.0    1
# 205.0    1
# 280.0    1
# 236.0    1
# 221.0    1
# 300.0    1
# 244.0    1
# 222.0    1
# 290.0    1
# 162.0    1
# 228.0    1
# 298.0    1
# 159.0    1
# 332.0    1
# 250.0    1
# 196.0    1
# 237.0    1
# 234.0    1
# Name: TOTCHOL, dtype: int64

# %%
dataset["AGE"].value_counts()
# Out:
# 52    6
# 58    5
# 46    5
# 49    4
# 43    4
# 48    3
# 55    3
# 54    3
# 51    3
# 64    3
# 47    3
# 50    2
# 44    2
# 38    2
# 41    2
# 56    2
# 39    2
# 60    2
# 53    2
# 63    1
# 67    1
# 70    1
# 66    1
# 35    1
# 62    1
# 61    1
# 57    1
# 45    1
# 42    1
# 72    1
# Name: AGE, dtype: int64

# %%
dataset["SYSBP"].value_counts()
# Out:
# 132.0    4
# 120.0    2
# 139.0    2
# 127.5    2
# 141.0    2
# 138.0    2
# 150.0    2
# 121.0    2
# 180.0    2
# 162.0    2
# 122.0    2
# 110.0    2
# 108.0    2
# 126.0    2
# 124.0    2
# 109.0    2
# 160.0    1
# 127.0    1
# 102.0    1
# 152.5    1
# 131.0    1
# 106.0    1
# 123.5    1
# 114.0    1
# 151.0    1
# 144.5    1
# 100.0    1
# 137.5    1
# 140.0    1
# 149.0    1
# 155.0    1
# 134.0    1
# 109.5    1
# 133.0    1
# 173.0    1
# 165.0    1
# 148.0    1
# 129.0    1
# 147.0    1
# 139.5    1
# 177.0    1
# 141.5    1
# 112.0    1
# 130.0    1
# 136.0    1
# 142.0    1
# 183.0    1
# 105.0    1
# 163.0    1
# 159.0    1
# 168.0    1
# Name: SYSBP, dtype: int64

# %%
dataset["DIABP"].value_counts()
# Out:
# 90.0     5
# 88.0     4
# 78.0     4
# 89.0     4
# 70.0     4
# 80.0     3
# 81.0     3
# 82.0     3
# 76.0     2
# 84.0     2
# 71.0     2
# 72.5     2
# 102.0    2
# 77.5     2
# 66.0     2
# 101.0    2
# 95.0     2
# 60.0     1
# 68.0     1
# 64.0     1
# 94.0     1
# 100.0    1
# 123.0    1
# 69.0     1
# 70.5     1
# 106.0    1
# 84.5     1
# 77.0     1
# 69.5     1
# 86.0     1
# 109.0    1
# 92.0     1
# 91.0     1
# 75.0     1
# 110.0    1
# 46.0     1
# 107.0    1
# 96.0     1
# Name: DIABP, dtype: int64

# %%
dataset["CURSMOKE"].value_counts()
# Out:
# 1    35
# 0    34
# Name: CURSMOKE, dtype: int64

# %%
dataset["CIGPDAY"].value_counts()
# Out:
# 0     34
# 20    10
# 30     9
# 10     4
# 15     2
# 40     2
# 5      1
# 6      1
# 7      1
# 9      1
# 23     1
# 35     1
# 50     1
# 60     1
# Name: CIGPDAY, dtype: int64

# %%
dataset["BMI"].value_counts()
# Out:
# 22.73    2
# 21.59    2
# 25.34    2
# 21.98    1
# 21.68    1
#         ..
# 21.77    1
# 31.31    1
# 26.88    1
# 30.05    1
# 21.35    1
# Name: BMI, Length: 65, dtype: int64

# %%
dataset["CVD"].value_counts()
# Out:
# 0    58
# 1    11
# Name: CVD, dtype: int64

# %%
dataset["HYPERTEN"].value_counts()
# Out:
# 1    56
# 0    13
# Name: HYPERTEN, dtype: int64

# %%
dataset["TIMEAP"].value_counts()
# Out:
# 8766    50
# 6410     3
# 6411     3
# 5592     3
# 8297     3
# 2956     2
# 373      2
# 146      1
# 1442     1
# 430      1
# Name: TIMEAP, dtype: int64

# %%
dataset["TIMEMI"].value_counts()
# Out:
# 8766    53
# 6411     3
# 5592     3
# 6384     3
# 2956     2
# 6438     2
# 146      1
# 1442     1
# 430      1
# Name: TIMEMI, dtype: int64

# %%
dataset["TIMEMIFC"].value_counts()
# Out:
# 8766    50
# 6411     3
# 5719     3
# 5592     3
# 6384     3
# 2956     2
# 6438     2
# 146      1
# 1442     1
# 430      1
# Name: TIMEMIFC, dtype: int64

# %%
dataset["TIMECHD"].value_counts()
# Out:
# 8766    45
# 6411     3
# 5719     3
# 5592     3
# 8297     3
# 6384     3
# 2956     2
# 6438     2
# 373      2
# 146      1
# 1442     1
# 430      1
# Name: TIMECHD, dtype: int64

# %%
dataset["TIMESTRK"].value_counts()
# Out:
# 8766    55
# 6410     3
# 6411     3
# 5592     3
# 2089     2
# 146      1
# 1442     1
# 430      1
# Name: TIMESTRK, dtype: int64

# %%
dataset["TIMECVD"].value_counts()
# Out:
# 8766    50
# 6411     3
# 5719     3
# 5592     3
# 6384     3
# 6438     2
# 2089     2
# 146      1
# 1442     1
# 430      1
# Name: TIMECVD, dtype: int64

# %%
dataset["TIMEDTH"].value_counts()
# Out:
# 8766    55
# 6410     3
# 6411     3
# 5592     3
# 2956     2
# 146      1
# 1442     1
# 430      1
# Name: TIMEDTH, dtype: int64

# %%
dataset["TIMEHYP"].value_counts()
# Out:
# 0       24
# 8766    11
# 2177     3
# 7951     3
# 1469     3
# 5933     3
# 4408     3
# 4285     3
# 723      3
# 8679     3
# 5226     3
# 2157     3
# 2212     2
# 1442     1
# 430      1
# Name: TIMEHYP, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
one = le.fit_transform(dataset["SEX"])

# %%
dataset["SEX"] = one

# %%
two = le.fit_transform(dataset["TOTCHOL"])

# %%
dataset["TOTCHOL"] = two

# %%
three = le.fit_transform(dataset["AGE"])

# %%
dataset["AGE"] = three

# %%
four = le.fit_transform(dataset["SYSBP"])

# %%
dataset["SYSBP"] = four

# %%
five = le.fit_transform(dataset["DIABP"])

# %%
dataset["DIABP"] = five

# %%
six = le.fit_transform(dataset["BMI"])

# %%
dataset["BMI"] = six

# %%
seven = le.fit_transform(dataset["TIMEAP"])

# %%
dataset["TIMEAP"] = seven

# %%
eight = le.fit_transform(dataset["TIMEMI"])

# %%
dataset["TIMEMI"] = eight

# %%
dataset
# Out:
#     Unnamed: 0  RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY  \
# 0            1    2448    0        4    2      3      7         0        0
# 1            2    2448    0        8   14     11      3         0        0
# 2            3    6238    1       26    8     11     17         0        0
# 3            4    6238    1       30   14      2      6         0        0
# 4            5    6238    1       22   20      4      3         0        0
# ..         ...     ...  ...      ...  ...    ...    ...       ...      ...
# 64          65   54224    0       42    9      1      4         1       20
# 65          66   55965    1       30   21      7     10         0        0
# 66          67   55965    1       28   26     15     18         0        0
# 67          68   55965    1       43   29      5      1         0        0
# 68          69   63156    0       15    0     21     25         1       20
#
# ...

# %%
dataset.corr()
# Out:
#               Unnamed: 0    RANDID           SEX   TOTCHOL           AGE  \
# Unnamed: 0  1.000000e+00  0.982953 -7.718170e-03  0.001152 -9.030217e-17
# RANDID      9.829530e-01  1.000000 -5.611637e-03 -0.017403 -8.259446e-03
# SEX        -7.718170e-03 -0.005612  1.000000e+00  0.074037  1.370320e-01
# TOTCHOL     1.151564e-03 -0.017403  7.403676e-02  1.000000  2.231575e-01
# AGE        -9.030217e-17 -0.008259  1.370320e-01  0.223157  1.000000e+00
# SYSBP      -3.525251e-02 -0.072366 -2.099048e-01 -0.212020  2.376524e-01
# DIABP      -8.940577e-02 -0.100759 -2.805269e-01 -0.241568 -1.401086e-01
# CURSMOKE    1.295399e-01  0.150145 -8.199201e-02  0.118720 -2.182902e-01
# CIGPDAY     1.086711e-01  0.124460 -9.168444e-03  0.151556 -1.282109e-01
# BMI        -1.671523e-01 -0.133542  9.546950e-02 -0.169661  1.670965e-01
# DIABETES    8.920610e-02  0.079348  1.507557e-01  0.034866  2.120643e-01
# BPMEDS     -1.294198e-01 -0.162294  3.760589e-02 -0.037140 -1.238120e-01
# ...
